# %% [markdown]
# # Titanic Project with Keras and Deep Learning

# %%
#pip install tensorflow

# %%
#!pip install keras

# %% [markdown]
# <img src='https://www.kdnuggets.com/wp-content/uploads/scalar-vector-matrix-tensor.jpg'>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('ttrain.csv')

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Wondered what is the survival rate based on Gender
survival_by_gender = df1.groupby('Sex')['Survived'].mean()
print("Survival rate by Gender:")
print(survival_by_gender)
# Out:
# Survival rate by Gender:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# <img src="https://esq.h-cdn.co/assets/16/48/2560x1440/hd-aspect-1480784516-weed.jpg" width="600" height="200">

# %%
df1.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 299          300         1       1
# 669          670         1       1
# 795          796         0       2
# 720          721         1       2
# 768          769         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 669  Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)  female   NaN      1
# 795                                 Otter, Mr. Richard    male  39.0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female   6.0      0
# 768                                Moran, Mr. Daniel J    male   NaN      1
#
#      Parch    Ticket      Fare    Cabin Embarked
# 299      1  PC 17558  247.5208  B58 B60        C
# 669      0     19996   52.0000     C126        S
# 795      0     28213   13.0000      NaN        S
# 720      1    248727   33.0000      NaN        S
# 768      0    371110   24.1500      NaN        Q

# %%
df1.info()
# There are a lot of different types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df2 = pd.read_csv('ttest.csv')

# %%
df2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
df = pd.concat([df1, df2])

# %%
df.shape
# Out:
# (1309, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
print('(mean, max, min, std)')
df['Fare'].mean(), df['Fare'].max(), df['Fare'].min(), df['Fare'].std()
# Out:
# (mean, max, min, std)
# (33.29547928134557, 512.3292, 0.0, 51.75866823917414)

# %%
df['Fare'].value_counts()
# Out:
# Fare
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
#            ..
# 7.7417      1
# 8.1583      1
# 8.4583      1
# 7.8000      1
# 7.7208      1
# Name: count, Length: 281, dtype: int64

# %%
df['Fare'].fillna(df['Fare'].mean(),inplace=True)

# %%
import seaborn as sns

# %%
df['Embarked']
# Embarked --> The port that they board
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 413    S
# 414    C
# 415    S
# 416    S
# 417    C
# Name: Embarked, Length: 1309, dtype: object

# %%
sns.histplot(df['Embarked']);

# %%
# He have just 2 null values in Embarked row, so I'm going to fill that up with S which in most common
df['Embarked'] = df['Embarked'].fillna('S')

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# dtype: int64

# %%
df['Cabin'].value_counts()
# Too complicated, but i can visit later
'''
# !!!
Visit Later
# !!!
'''
# Out:
# '\n!!!\nVisit Later\n!!!\n'

# %%
del df['Cabin']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 122.7+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Embarked
# 0        0           A/5 21171    7.2500        S
# 1        0            PC 17599   71.2833        C
# 2        0    STON/O2. 3101282    7.9250        S
# 3        0              113803   53.1000        S
# 4        0              373450    8.0500        S
# ..     ...                 ...       ...      ...
# 413      0           A.5. 3236    8.0500        S
# 414      0            PC 17758  108.9000        C
# 415      0  SOTON/O.Q. 3101262    7.2500        S
# 416      0              359309    8.0500        S
# 417      1                2668   22.3583        C
#
# [1309 rows x 11 columns]

# %%
# Parch --> Number of Parents and Children (on board)
# SibSp --> Sibling and Spouse
df['Family'] = df['Parch'] + df['SibSp']

# %%
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=True)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Mlle          2
# Major         2
# Ms            2
# Lady          1
# Sir           1
# Mme           1
# Don           1
# Capt          1
# Countess      1
# Jonkheer      1
# Dona          1
# Name: count, dtype: int64

# %%
# Replacing those that are misspelled
df['Title'] = df['Title'].replace(['Lady', 'Countess', 'Capt', 'Col', 'Don', 
                                       'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr        757
# Miss      264
# Mrs       198
# Master     61
# Rare       29
# Name: count, dtype: int64

# %%
df = df.drop('Name', axis = 1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked', 'Family', 'Title'],
#       dtype='object')

# %%
df['Age'].mean()
# Out:
# 29.881137667304014

# %%
df['Age'] = df['Age'].fillna(df.groupby('Title')['Age'].transform('median'))
# This part is from Ömer Can

# %%
master = df[df['Title'] == 'Master']

# %%
master['Age'].mean()
# Out:
# 5.2881967213114764

# %%
master
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch     Ticket  \
# 7              8       0.0       3  male   2.0      3      1     349909
# 16            17       0.0       3  male   2.0      4      1     382652
# 50            51       0.0       3  male   7.0      4      1    3101295
# 59            60       0.0       3  male  11.0      5      2    CA 2144
# 63            64       0.0       3  male   4.0      3      2     347088
# ..           ...       ...     ...   ...   ...    ...    ...        ...
# 360         1252       NaN       3  male  14.5      8      2   CA. 2343
# 379         1271       NaN       3  male   5.0      4      2     347077
# 389         1281       NaN       3  male   6.0      3      1     349909
# 392         1284       NaN       3  male  13.0      0      2  C.A. 2673
# 417         1309       NaN       3  male   4.0      1      1       2668
#
#         Fare Embarked  Family   Title
# 7    21.0750        S       4  Master
# 16   29.1250        Q       5  Master
# 50   39.6875        S       5  Master
# 59   46.9000        S       7  Master
# 63   27.9000        S       5  Master
# ..       ...      ...     ...     ...
# 360  69.5500        S      10  Master
# 379  31.3875        S       6  Master
# 389  21.0750        S       4  Master
# 392  20.2500        S       2  Master
# 417  22.3583        C       2  Master
#
# [61 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived       418
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Family           0
# Title            0
# dtype: int64

# %%
df.corr(numeric_only = True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.024480 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.072058 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.392047  0.060832  0.018322
# Age             0.024480 -0.072058 -0.392047  1.000000 -0.214327 -0.129954
# SibSp          -0.055224 -0.035322  0.060832 -0.214327  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.129954  0.373587  1.000000
# Fare            0.031416  0.257307 -0.558477  0.180640  0.160224  0.221522
# Family         -0.031437  0.016639  0.050027 -0.212004  0.861952  0.792296
#
#                  Fare    Family
# PassengerId  0.031416 -0.031437
# Survived     0.257307  0.016639
# Pclass      -0.558477  0.050027
# Age          0.180640 -0.212004
# SibSp        0.160224  0.861952
# Parch        0.221522  0.792296
# Fare         1.000000  0.226465
# Family       0.226465  1.000000

# %%
df = df.drop('Ticket', axis = 1)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  Family  \
# 0         0.0       3    male  22.0      1      0    7.2500        S       1
# 1         1.0       1  female  38.0      1      0   71.2833        C       1
# 2         1.0       3  female  26.0      0      0    7.9250        S       0
# 3         1.0       1  female  35.0      1      0   53.1000        S       1
# 4         0.0       3    male  35.0      0      0    8.0500        S       0
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 413       NaN       3    male  29.0      0      0    8.0500        S       0
# 414       NaN       1  female  39.0      0      0  108.9000        C       0
# 415       NaN       3    male  38.5      0      0    7.2500        S       0
# 416       NaN       3    male  29.0      0      0    8.0500        S       0
# 417       NaN       3    male   4.0      1      1   22.3583        C       2
#
#       Title
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
# ..      ...
# 413      Mr
# 414    Rare
# 415      Mr
# 416      Mr
# 417  Master
#
# [1309 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Survived    418
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# Family        0
# Title         0
# dtype: int64

# %%
df = pd.get_dummies(df, drop_first = True)

# %%
df.info()
# With get_dummies, it turns into sth like this:
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    float64
#  1   Pclass      1309 non-null   int64
#  2   Age         1309 non-null   float64
#  3   SibSp       1309 non-null   int64
#  4   Parch       1309 non-null   int64
#  5   Fare        1309 non-null   float64
#  6   Family      1309 non-null   int64
#  7   Sex_male    1309 non-null   bool
#  8   Embarked_Q  1309 non-null   bool
#  9   Embarked_S  1309 non-null   bool
#  10  Title_Miss  1309 non-null   bool
#  11  Title_Mr    1309 non-null   bool
#  12  Title_Mrs   1309 non-null   bool
#  13  Title_Rare  1309 non-null   bool
# dtypes: bool(7), float64(3), int64(4)
# memory usage: 90.8 KB

# %%
x, y = df[:891].drop('Survived', axis = 1), df[:891][['Survived']]

# %%
x.shape
# Out:
# (891, 13)

# %%
y.shape
# Out:
# (891, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
def result_func(model, count):
    predict_x = model.predict(df[891:].drop('Survived', axis = 1))
    predict_x = np.array([1.23456789e+30, 9.87654321e+30], dtype=np.float32)
    predict_x = predict_x.astype(np.float64)
    result_dataset = pd.DataFrame()
    result_dataset['PassengerId'] = df[891:]['PassengerId']
    result_dataset['Predict'] = predict_x
    result_dataset['Survived'] = result_dataset['Predict'].map(lambda s:1 if s>=0.5 else 0)
    print(result_dataset['Survived'].value_counts().plot.bar())
    result_dataset.drop('Predict', axis = 1).to_csv('titanic_deep_learning_result{}.csv'.format(count), index = False)
    return result_dataset

# %%
model = Sequential()
model.add(Dense(14, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(6, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(x, y, epochs = 150, batch_size = 10, verbose = 1)
# Out:
# Epoch 1/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - accuracy: 0.5057 - loss: 0.7358
# Epoch 2/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.7004 - loss: 0.6337
# Epoch 3/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.7101 - loss: 0.5781
# Epoch 4/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.6989 - loss: 0.6047
# Epoch 5/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7318 - loss: 0.5701
# Epoch 6/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.7355 - loss: 0.5352
# Epoch 7/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.7274 - loss: 0.5308
# Epoch 8/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.7638 - loss: 0.5026
# Epoch 9/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7776 - loss: 0.4918
# Epoch 10/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.8174 - loss: 0.4571
# Epoch 11/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7805 - loss: 0.4925
# Epoch 12/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.8120 - loss: 0.4435
# Epoch 13/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7861 - loss: 0.4652
# Epoch 14/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7979 - loss: 0.4266
# Epoch 15/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7734 - loss: 0.4756
# Epoch 16/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8141 - loss: 0.4503
# Epoch 17/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7992 - loss: 0.4427
# Epoch 18/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8112 - loss: 0.4286
# Epoch 19/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8223 - loss: 0.4198
# Epoch 20/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8033 - loss: 0.4360
# Epoch 21/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8119 - loss: 0.4348
# Epoch 22/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8084 - loss: 0.4451
# Epoch 23/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8081 - loss: 0.4262
# Epoch 24/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8140 - loss: 0.4253
# Epoch 25/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8314 - loss: 0.4272
# Epoch 26/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8059 - loss: 0.4290
# Epoch 27/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8230 - loss: 0.4157
# Epoch 28/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8193 - loss: 0.4042
# Epoch 29/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.7910 - loss: 0.4556
# Epoch 30/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.8171 - loss: 0.4200
# Epoch 31/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.8054 - loss: 0.4384
# Epoch 32/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.8001 - loss: 0.4419
# Epoch 33/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.8072 - loss: 0.4306
# Epoch 34/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.8339 - loss: 0.4135
# Epoch 35/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.8383 - loss: 0.4023
# Epoch 36/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8051 - loss: 0.4290
# Epoch 37/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8150 - loss: 0.4220
# Epoch 38/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7904 - loss: 0.4445
# Epoch 39/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8092 - loss: 0.4346
# Epoch 40/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.8156 - loss: 0.4215
# Epoch 41/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8288 - loss: 0.4082
# Epoch 42/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8252 - loss: 0.4187
# Epoch 43/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.8264 - loss: 0.4160
# Epoch 44/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.8005 - loss: 0.4431
# Epoch 45/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8130 - loss: 0.4175
# Epoch 46/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8082 - loss: 0.4921
# Epoch 47/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8142 - loss: 0.4184
# Epoch 48/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8357 - loss: 0.4045
# Epoch 49/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8065 - loss: 0.4214
# Epoch 50/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8110 - loss: 0.4077
# Epoch 51/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8492 - loss: 0.3891
# Epoch 52/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8167 - loss: 0.4275
# Epoch 53/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.8356 - loss: 0.4130
# Epoch 54/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.8130 - loss: 0.4306
# Epoch 55/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.8119 - loss: 0.4562
# Epoch 56/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.8260 - loss: 0.4155
# Epoch 57/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.8123 - loss: 0.4239
# Epoch 58/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.8379 - loss: 0.4089
# Epoch 59/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.8269 - loss: 0.4135
# Epoch 60/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.7986 - loss: 0.4339
# Epoch 61/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.8413 - loss: 0.3828
# Epoch 62/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8167 - loss: 0.4146
# Epoch 63/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8367 - loss: 0.3941
# Epoch 64/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8123 - loss: 0.4222
# Epoch 65/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7977 - loss: 0.4295
# Epoch 66/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8248 - loss: 0.4311
# Epoch 67/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8392 - loss: 0.3673
# Epoch 68/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.8453 - loss: 0.4196
# Epoch 69/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8397 - loss: 0.3915
# Epoch 70/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8316 - loss: 0.3998
# Epoch 71/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8187 - loss: 0.4214
# Epoch 72/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8477 - loss: 0.3852
# Epoch 73/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8569 - loss: 0.3746
# Epoch 74/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8021 - loss: 0.4159
# Epoch 75/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8425 - loss: 0.3573
# Epoch 76/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.4221
# Epoch 77/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8026 - loss: 0.4400
# Epoch 78/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.8294 - loss: 0.4264
# Epoch 79/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8174 - loss: 0.4215
# Epoch 80/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.8348 - loss: 0.3741
# Epoch 81/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8412 - loss: 0.3906
# Epoch 82/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8019 - loss: 0.4346
# Epoch 83/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.8222 - loss: 0.4074
# Epoch 84/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8435 - loss: 0.3783
# Epoch 85/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8603 - loss: 0.3830
# Epoch 86/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8167 - loss: 0.4151
# Epoch 87/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8283 - loss: 0.3980
# Epoch 88/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8291 - loss: 0.3997
# Epoch 89/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8311 - loss: 0.3820
# Epoch 90/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8384 - loss: 0.3852
# Epoch 91/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8508 - loss: 0.3767
# Epoch 92/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8532 - loss: 0.3848
# Epoch 93/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8342 - loss: 0.3865
# Epoch 94/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8093 - loss: 0.4003
# Epoch 95/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8240 - loss: 0.4133
# Epoch 96/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8202 - loss: 0.4121
# Epoch 97/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.8219 - loss: 0.3929
# Epoch 98/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.8520 - loss: 0.3812
# Epoch 99/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.8274 - loss: 0.3952
# Epoch 100/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8391 - loss: 0.3703
# Epoch 101/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.8363 - loss: 0.3872
# Epoch 102/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8664 - loss: 0.3474
# Epoch 103/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8278 - loss: 0.4124
# Epoch 104/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.8318 - loss: 0.3934
# Epoch 105/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.8386 - loss: 0.3830
# Epoch 106/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8321 - loss: 0.4690
# Epoch 107/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8519 - loss: 0.3726
# Epoch 108/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8098 - loss: 0.4272
# Epoch 109/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8180 - loss: 0.4123
# Epoch 110/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8201 - loss: 0.4069
# Epoch 111/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8416 - loss: 0.3748
# Epoch 112/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8373 - loss: 0.3646
# Epoch 113/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8175 - loss: 0.3987
# Epoch 114/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8471 - loss: 0.3728
# Epoch 115/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8627 - loss: 0.3633
# Epoch 116/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8331 - loss: 0.4019
# Epoch 117/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8104 - loss: 0.4126
# Epoch 118/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.8235 - loss: 0.4062
# Epoch 119/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8231 - loss: 0.4079
# Epoch 120/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.8291 - loss: 0.3996
# Epoch 121/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8141 - loss: 0.4368
# Epoch 122/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.8480 - loss: 0.3680
# Epoch 123/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8446 - loss: 0.3667
# Epoch 124/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8325 - loss: 0.3716
# Epoch 125/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8171 - loss: 0.4132
# Epoch 126/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.8488 - loss: 0.3769
# Epoch 127/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8454 - loss: 0.3606
# Epoch 128/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8485 - loss: 0.3560
# Epoch 129/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.8521 - loss: 0.3630
# Epoch 130/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8204 - loss: 0.3991
# Epoch 131/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8363 - loss: 0.3859
# Epoch 132/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8439 - loss: 0.3655
# Epoch 133/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8224 - loss: 0.3869
# Epoch 134/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8310 - loss: 0.3884
# Epoch 135/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8397 - loss: 0.3961
# Epoch 136/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.8256 - loss: 0.3752
# Epoch 137/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8365 - loss: 0.3638
# Epoch 138/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8386 - loss: 0.3817
# Epoch 139/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8553 - loss: 0.3746
# Epoch 140/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.8454 - loss: 0.3586
# Epoch 141/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8460 - loss: 0.3668
# Epoch 142/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8134 - loss: 0.3993
# Epoch 143/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8233 - loss: 0.4059
# Epoch 144/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8192 - loss: 0.3968
# Epoch 145/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8369 - loss: 0.3709
# Epoch 146/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8408 - loss: 0.3581
# Epoch 147/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.8147 - loss: 0.4107
# Epoch 148/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8453 - loss: 0.3962
# Epoch 149/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8307 - loss: 0.3683
# Epoch 150/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8197 - loss: 0.4175

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                      │ (None, 14)                  │             196 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 10)                  │             150 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 6)                   │              66 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,259 (4.92 KB)
#  Trainable params: 419 (1.64 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 840 (3.29 KB)

# %%
scores = model.evaluate(x, y)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8285 - loss: 0.4197

# %%
result_func(model, 1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step
# Axes(0.125,0.11;0.775x0.77)
#         Predict  Survived
# 0  1.234568e+30         1
# 1  9.876543e+30         1

# %%
result_dataset = pd.DataFrame()

# %%
result_dataset['Predict'] = predict_x

# %%
predict_x
# Out:
# array([[7.89404511e-02],
#        [1.70381710e-01],
#        [4.32964228e-02],
#        [7.45495781e-02],
#        [4.42386985e-01],
#        [8.73979777e-02],
#        [5.33280194e-01],
#        [5.21488413e-02],
#        [6.52156353e-01],
#        [6.52876794e-02],
#        [1.00309685e-01],
#        [1.38463020e-01],
#        [9.48256254e-01],
#        [7.06349462e-02],
#        [9.58545089e-01],
#        [9.17658627e-01],
#        [1.07858904e-01],
#        [9.57528949e-02],
#        [3.07476223e-01],
#        [3.22970480e-01],
#        [2.70103067e-01],
#        [4.06731278e-01],
#        [9.45328414e-01],
#        [1.92342356e-01],
#        [6.00922704e-01],
#        [6.11166097e-02],
#        [9.39956605e-01],
#        [1.06382750e-01],
#        [2.10413456e-01],
#        [4.20271046e-02],
#        [3.50429565e-02],
#        [9.79321599e-02],
#        [3.91208768e-01],
#        [4.04681951e-01],
#        [2.69890040e-01],
#        [9.75548103e-02],
#        [4.15144116e-01],
#        [4.49528337e-01],
#        [5.99099398e-02],
#        [2.12419063e-01],
#        [5.70995063e-02],
#        [2.76535511e-01],
#        [6.09368607e-02],
#        [8.28933239e-01],
#        [9.56636965e-01],
#        [7.57426247e-02],
#        [2.02863231e-01],
#        [8.93193036e-02],
#        [9.82546031e-01],
#        [3.77787083e-01],
#        [1.55631050e-01],
#        [7.35926628e-02],
#        [3.59455824e-01],
#        [2.21647710e-01],
#        [6.73403516e-02],
#        [6.32172525e-02],
#        [7.95037970e-02],
#        [8.00701603e-02],
#        [5.27989604e-02],
#        [9.07471776e-01],
#        [8.21965709e-02],
#        [7.91580528e-02],
#        [7.98960030e-02],
#        [6.38216853e-01],
#        [1.37669042e-01],
#        [8.74769330e-01],
#        [6.90234303e-01],
#        [2.35422894e-01],
#        [3.25291842e-01],
#        [4.00220931e-01],
#        [6.14628911e-01],
#        [7.00053498e-02],
#        [3.28419924e-01],
#        [3.46348852e-01],
#        [9.26993072e-01],
#        [1.87562481e-01],
#        [9.72854197e-02],
#        [8.80840063e-01],
#        [7.58703053e-02],
#        [6.14628911e-01],
#        [8.75424087e-01],
#        [7.26925433e-02],
#        [1.15798645e-01],
#        [1.00309685e-01],
#        [1.10022105e-01],
#        [5.31018935e-02],
#        [5.81740141e-01],
#        [4.65041965e-01],
#        [6.39119327e-01],
#        [9.52837050e-01],
#        [6.29470348e-01],
#        [1.02079220e-01],
#        [8.56338739e-01],
#        [9.72854197e-02],
#        [3.72486383e-01],
#        [7.77483806e-02],
#        [8.86056900e-01],
#        [9.97306108e-02],
#        [4.33040142e-01],
#        [8.74837413e-02],
#        [9.68469858e-01],
#        [9.50964540e-02],
#        [8.93193036e-02],
#        [8.30680728e-02],
#        [4.56654638e-01],
#        [4.26994525e-02],
#        [7.85012469e-02],
#        [8.93193036e-02],
#        [8.52003545e-02],
#        [9.72414985e-02],
#        [1.12970427e-01],
#        [6.40172005e-01],
#        [9.13331568e-01],
#        [6.64147258e-01],
#        [8.90954733e-01],
#        [8.91882852e-02],
#        [9.65267345e-02],
#        [8.63787293e-01],
#        [3.12000394e-01],
#        [8.42175961e-01],
#        [7.83351958e-01],
#        [1.04173668e-01],
#        [9.64334369e-01],
#        [1.03304945e-01],
#        [8.93193036e-02],
#        [3.93773168e-01],
#        [6.69075623e-02],
#        [5.02835155e-01],
#        [1.05892025e-01],
#        [7.02412650e-02],
#        [9.13224593e-02],
#        [1.52442604e-01],
#        [9.68943015e-02],
#        [9.60662365e-02],
#        [5.59151098e-02],
#        [7.30952471e-02],
#        [1.12319082e-01],
#        [6.44196421e-02],
#        [4.02896881e-01],
#        [6.65926374e-04],
#        [2.39989031e-02],
#        [9.33750093e-01],
#        [1.39073730e-02],
#        [1.16492927e-01],
#        [1.79362074e-01],
#        [4.38492820e-02],
#        [3.32531720e-01],
#        [6.69695437e-02],
#        [2.76535511e-01],
#        [3.23791765e-02],
#        [9.63157952e-01],
#        [1.05127923e-01],
#        [1.74244307e-02],
#        [2.64042854e-01],
#        [3.30060236e-02],
#        [7.77416900e-02],
#        [9.09180462e-01],
#        [3.96165699e-01],
#        [1.79361790e-01],
#        [4.38059032e-01],
#        [6.38516605e-01],
#        [8.38407278e-01],
#        [7.66281128e-01],
#        [9.75751504e-02],
#        [4.37030904e-02],
#        [5.11988819e-01],
#        [3.01098049e-01],
#        [3.21824253e-02],
#        [9.45365191e-01],
#        [4.48181212e-01],
#        [1.00773312e-01],
#        [1.09989487e-01],
#        [6.68849051e-02],
#        [1.01115331e-01],
#        [2.69297557e-03],
#        [8.79397154e-01],
#        [9.33938980e-01],
#        [2.54724503e-01],
#        [6.73995018e-01],
#        [9.29219961e-01],
#        [7.58703053e-02],
#        [1.04907304e-01],
#        [9.55562174e-01],
#        [8.93193036e-02],
#        [8.44629884e-01],
#        [8.47068503e-02],
#        [7.08988369e-01],
#        [1.04248695e-01],
#        [4.32236213e-03],
#        [1.10603407e-01],
#        [7.76569322e-02],
#        [2.70596981e-01],
#        [3.60185921e-01],
#        [5.34054711e-02],
#        [9.61219668e-01],
#        [8.64716396e-02],
#        [8.71562004e-01],
#        [4.55253065e-01],
#        [8.92469361e-02],
#        [3.96757126e-01],
#        [7.60901153e-01],
#        [9.80540156e-01],
#        [4.30384606e-01],
#        [7.88148940e-01],
#        [8.79099965e-02],
#        [3.26693177e-01],
#        [4.37996686e-01],
#        [8.18486586e-02],
#        [9.11095142e-01],
#        [7.61917531e-02],
#        [3.78111787e-02],
#        [9.78621170e-02],
#        [2.56175399e-01],
#        [8.19945216e-01],
#        [1.04919910e-01],
#        [2.82293081e-01],
#        [6.43766761e-01],
#        [5.67907430e-02],
#        [8.59669328e-01],
#        [9.72854197e-02],
#        [7.26386189e-01],
#        [7.02481046e-02],
#        [8.35510969e-01],
#        [6.98482320e-02],
#        [9.14520204e-01],
#        [4.38506782e-01],
#        [7.03554749e-02],
#        [6.39119327e-01],
#        [5.29973321e-02],
#        [1.15941696e-01],
#        [2.39877969e-01],
#        [9.30628300e-01],
#        [1.13395326e-01],
#        [8.92374590e-02],
#        [2.32517943e-01],
#        [7.33524859e-02],
#        [2.85515189e-01],
#        [9.14008841e-02],
#        [5.37030756e-01],
#        [9.48935330e-01],
#        [9.11259592e-01],
#        [6.85463667e-01],
#        [8.14239234e-02],
#        [1.00474805e-01],
#        [8.93274665e-01],
#        [3.35415095e-01],
#        [8.90862107e-01],
#        [3.61927748e-02],
#        [8.42175961e-01],
#        [5.77971697e-01],
#        [9.46685314e-01],
#        [7.34687671e-02],
#        [1.40641287e-01],
#        [6.26176521e-02],
#        [9.33032930e-02],
#        [1.00773260e-01],
#        [8.93193036e-02],
#        [9.06418785e-02],
#        [7.14131474e-01],
#        [6.98156208e-02],
#        [3.32582295e-02],
#        [6.99399263e-02],
#        [7.73878098e-01],
#        [7.87175179e-01],
#        [1.17450930e-01],
#        [1.00309685e-01],
#        [1.35884151e-01],
#        [1.00773312e-01],
#        [4.15144116e-01],
#        [8.20271149e-02],
#        [3.12142760e-01],
#        [8.93193036e-02],
#        [9.44200873e-01],
#        [6.70485020e-01],
#        [1.01090476e-01],
#        [7.89195716e-01],
#        [1.08589545e-01],
#        [6.15592487e-02],
#        [7.17772022e-02],
#        [1.01180814e-01],
#        [4.24179405e-01],
#        [9.42147136e-01],
#        [6.39119327e-01],
#        [4.84659702e-01],
#        [8.81740868e-01],
#        [7.32161999e-02],
#        [9.90174785e-02],
#        [1.39095485e-01],
#        [1.01115331e-01],
#        [9.72854197e-02],
#        [4.01650697e-01],
#        [5.06872535e-01],
#        [1.01115331e-01],
#        [3.13437372e-01],
#        [8.37965161e-02],
#        [8.10635313e-02],
#        [9.71126735e-01],
#        [4.20271046e-02],
#        [3.69638234e-01],
#        [1.01014115e-01],
#        [8.98478702e-02],
#        [6.89227059e-02],
#        [2.29479559e-02],
#        [6.19663335e-02],
#        [6.39119327e-01],
#        [8.40722442e-01],
#        [3.62892784e-02],
#        [9.72275496e-01],
#        [1.06111467e-01],
#        [3.68587732e-01],
#        [7.96995237e-02],
#        [1.02728702e-01],
#        [1.00920834e-01],
#        [4.13567334e-01],
#        [9.70428228e-01],
#        [6.96515918e-01],
#        [1.25744641e-01],
#        [1.27987787e-01],
#        [8.78035426e-02],
#        [8.86080265e-02],
#        [8.30680728e-02],
#        [1.19120106e-01],
#        [6.44196421e-02],
#        [2.39851534e-01],
#        [9.11281884e-01],
#        [8.18232447e-02],
#        [6.94602728e-01],
#        [3.05928290e-01],
#        [8.97841379e-02],
#        [9.00556147e-02],
#        [6.46392465e-01],
#        [2.53774822e-01],
#        [1.01090476e-01],
#        [6.08967423e-01],
#        [8.70722234e-02],
#        [2.61238456e-01],
#        [8.75680745e-02],
#        [3.30567472e-02],
#        [1.54142991e-01],
#        [9.73828614e-01],
#        [1.33576021e-01],
#        [8.88110921e-02],
#        [2.89405521e-04],
#        [7.33811617e-01],
#        [8.68356943e-01],
#        [4.76008356e-01],
#        [6.44196421e-02],
#        [4.04954374e-01],
#        [7.66208321e-02],
#        [7.77743459e-01],
#        [9.71333086e-01],
#        [8.79099965e-02],
#        [2.60148108e-01],
#        [2.96181217e-02],
#        [9.11958456e-01],
#        [1.09714501e-01],
#        [8.30663443e-01],
#        [1.00640170e-01],
#        [8.93193036e-02],
#        [6.01593852e-01],
#        [2.05926178e-03],
#        [9.22397256e-01],
#        [8.75715137e-01],
#        [7.45495781e-02],
#        [9.61727142e-01],
#        [1.38558205e-02],
#        [5.30565009e-02],
#        [9.04347539e-01],
#        [9.70108211e-01],
#        [8.77228603e-02],
#        [1.19482122e-01],
#        [9.49736297e-01],
#        [5.76988906e-02],
#        [1.01358458e-01],
#        [9.16863680e-01],
#        [9.05431509e-01],
#        [3.50715280e-01],
#        [1.06785886e-01],
#        [2.10962877e-01],
#        [4.54042964e-02],
#        [8.93193036e-02],
#        [8.00408795e-02],
#        [6.21593714e-01],
#        [5.90499461e-01],
#        [7.24026114e-02],
#        [7.51107216e-01],
#        [7.42797479e-02],
#        [6.06956817e-02],
#        [7.83558041e-02],
#        [9.38178971e-02],
#        [2.59249091e-01],
#        [8.35323930e-01],
#        [8.33672345e-01],
#        [8.08833241e-02],
#        [3.10636461e-02],
#        [9.54066873e-01],
#        [7.87600577e-02],
#        [9.29063439e-01],
#        [6.71926513e-02],
#        [8.54376480e-02],
#        [9.30013597e-01],
#        [4.11349759e-02],
#        [9.40683722e-01],
#        [2.70148069e-01],
#        [1.73359886e-01],
#        [1.14146009e-01],
#        [1.05688646e-01],
#        [5.60760498e-02],
#        [6.38065219e-01],
#        [6.89879239e-01],
#        [6.39119327e-01],
#        [9.19404149e-01],
#        [3.34886640e-01],
#        [9.72854197e-02],
#        [8.21406543e-01],
#        [6.56078011e-02],
#        [9.72854197e-02],
#        [9.55121398e-01]], dtype=float32)
